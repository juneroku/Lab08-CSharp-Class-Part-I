// %% [markdown]
// # Lab 8 Exercise 2
//
// ## การประกาศสมาชิกในคลาส (fields)

// %% [markdown]
// 1. สร้าง console application project
//
// ```
//     dotnet new console --name Lab08_Ex02
// ```

// %% [markdown]
// 2. เปลี่ยน code ให้เป็นดังต่อไปนี้ (ตัวเลขข้างหน้า คือหมายเลขบรรทัด ไว้สำหรับอ้างอิง)
//
// > ```csharp
// >  1. Person p = new Person();
// >  2. p.name = "Rambo";
// >  3. p.id = "1987";
// >  4. p.income = 2500;
// >  5. System.Console.WriteLine($"Type of p is {p.GetType()}");
// >  6. System.Console.WriteLine($"p.name = {p.name}\ttype = {p.name.GetType()}");
// >  7. System.Console.WriteLine($"p.id = {p.id}\ttype = {p.id.GetType()}");
// >  8. System.Console.WriteLine($"p.income = {p.income}\ttype = {p.income.GetType()}");
// >  9.
// > 10. class Person
// > 11. {
// > 12.     string name;
// > 13.     string id;
// > 14.     int income;
// > 15. }
// > ```

// %% [markdown]
// 3. Build project โดยการใช้คำสั่ง
//
// ```
//     dotnet build  Lab08_Ex02
// ```

// %% [markdown]
// 4. บันทึกผลที่ได้จากการรันคำสั่งในข้อ 3

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 5. Run project โดยการใช้คำสั่ง
//
// ```
//     dotnet run --project Lab08_Ex02
// ```

// %% [markdown]
// 6. บันทึกผลที่ได้จากการรันคำสั่งในข้อ 5

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 7. อธิบายสิ่งที่พบในการทดลอง

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// ไม่สามารถ build และ run ได้ แต่ถ้ารันได้โค้ดนี้จะแสดงการสร้างและใช้งานออบเจ็กต์ของคลาส Person ในภาษา C# รวมถึงการตรวจสอบชนิดข้อมูลของสมาชิกต่างๆ ภายในออบเจ็กต์

// %% [markdown]
// 8. นำ code ในข้อ 2 มารันบน polyglot notebook  โดยใส่ใน  code cell ด้านล่างนี้

// %%
Person p = new Person();
p.name = "Rambo";
p.id = "1987";
p.income = 2500;
System.Console.WriteLine($"Type of p is {p.GetType()}");
System.Console.WriteLine($"p.name = {p.name}\ttype = {p.name.GetType()}");
System.Console.WriteLine($"p.id = {p.id}\ttype = {p.id.GetType()}");
System.Console.WriteLine($"p.income = {p.income}\ttype = {p.income.GetType()}");
 
class Person
 {
    string name;
    string id;
    int income;
 }
// Out:
// (2,3): error CS0122: 'Person.name' is inaccessible due to its protection level
//
// (3,3): error CS0122: 'Person.id' is inaccessible due to its protection level
//
// (4,3): error CS0122: 'Person.income' is inaccessible due to its protection level
//
// (6,40): error CS0122: 'Person.name' is inaccessible due to its protection level
//
// (6,57): error CS0122: 'Person.name' is inaccessible due to its protection level
//
// (7,38): error CS0122: 'Person.id' is inaccessible due to its protection level
//
// (7,53): error CS0122: 'Person.id' is inaccessible due to its protection level
//
// (8,42): error CS0122: 'Person.income' is inaccessible due to its protection level
//
// (8,61): error CS0122: 'Person.income' is inaccessible due to its protection level

// %% [markdown]
// 8.1 ผลการรันเป็นอย่างไร

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 8.2 เหมือนหรือค่างจาก console application อย่างไร

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// ไม่สามารถรันได้เหมือนกัน

// %% [markdown]
// ## คำถาม

// %% [markdown]
// 1. Field ในภาษา C# คืออะไร

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// Field ในภาษา C# คือตัวแปรที่ประกาศไว้ภายในคลาสหรือสตรัก เพื่อเก็บข้อมูลที่เกี่ยวข้องกับออบเจ็กต์ของคลาสนั้นๆ Field เปรียบเสมือนคุณลักษณะหรือสถานะของออบเจ็กต์

// %% [markdown]
// 2. Field มีหน้าที่อะไรใน class

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// Field มีหน้าที่ในการเก็บข้อมูลที่จำเป็นสำหรับคลาสหรือออบเจ็กต์ ข้อมูลเหล่านี้อาจเป็นค่าต่างๆ เช่น ชื่อ, อายุ, ราคา, หรือสถานะ Field ช่วยให้เราสามารถจัดการและเข้าถึงข้อมูลของออบเจ็กต์ได้อย่างมีประสิทธิภาพ

// %% [markdown]
// 3. การประกาศ Field ทำได้อย่างไร ให้อธิบายรูปแบบการประกาศ field ในคลาส

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// การประกาศ Field ในคลาสทำได้โดยการระบุชนิดข้อมูล ตามด้วยชื่อ Field และอาจมีตัวระบุการเข้าถึง (access modifier) กำกับไว้ด้วย รูปแบบทั่วไปคือ:

// %% [markdown]
// 4. Field และ Variable แตกต่างกันอย่างไร

// %% [markdown]
// Field: เป็นตัวแปรที่ประกาศไว้ในคลาสหรือสตรัก เป็นส่วนหนึ่งของออบเจ็กต์ ใช้สำหรับเก็บข้อมูลที่เกี่ยวข้องกับออบเจ็กต์
//
// Variable: เป็นตัวแปรที่ประกาศไว้ในเมธอดหรือบล็อกโค้ดอื่นๆ ใช้สำหรับเก็บข้อมูลชั่วคราวภายในขอบเขตของเมธอดหรือบล็อกโค้ดนั้นๆ เมื่อเมธอดหรือบล็อกโค้ดสิ้นสุดการทำงาน Variable ก็จะถูกทำลาย

// %% [markdown]
// 5. เมื่อไหร่ควรใช้ Field และเมื่อไหร่ควรใช้ Variable

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// Field: ควรใช้เมื่อต้องการเก็บข้อมูลที่เกี่ยวข้องกับออบเจ็กต์ และต้องการให้ข้อมูลนั้นอยู่กับออบเจ็กต์ตลอดอายุการใช้งานของออบเจ็กต์
//
// Variable: ควรใช้เมื่อต้องการเก็บข้อมูลชั่วคราวที่ใช้เฉพาะภายในเมธอดหรือบล็อกโค้ด

// %% [markdown]
// 6. ในโปรแกรมการทดลองนี้ มี field หรือไม่ อยู่ในบรรทัดที่เท่าไหร่

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// name อยู่ในบรรทัดที่ 10
//
// id อยู่ในบรรทัดที่ 11
//
// income อยู่ในบรรทัดที่ 12

// %% [markdown]
// 7. ผลจากการรันโปรแกรมใน Console Application และใน polyglot notebook เหมือนหรือแตกต่างกันอย่างไร

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// ผลจากการรันโปรแกรมใน Console Application และใน Polyglot Notebook error เหมือนกัน
